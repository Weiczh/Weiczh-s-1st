# %%
from utils import get_rows #import the functions from the utils.py
from utils import window_search
from utils import search

# %%
rows=get_rows() #get the top 500 computers' data

# %%
window_search(rows) #search the matching items you like from the data
# Out:
# Summit
# [['Rank', 'System', 'Cores', 'Rmax', 'Rpeak', 'Power'], ['2', 'Summit-IBMPowerSystemAC922, IBMPOWER922C3.07GHz, NVIDIAVoltaGV100, Dual-railMellanoxEDRInfiniband, IBMDOE/SC/OakRidgeNationalLaboratoryUnitedStates', '2414592', '148.60', '200.79', '10096']]

# %%
search("China",rows) # an example to search the supercomputers from China
# Out:
# [['Rank', 'System', 'Cores', 'Rmax', 'Rpeak', 'Power'],
#  ['4',
#   'SunwayTaihuLight-SunwayMPP, SunwaySW26010260C1.45GHz, Sunway, NRCPCNationalSupercomputingCenterinWuxiChina',
#   '10649600',
#   '93.01',
#   '125.44',
#   '15371'],
#  ['7',
#   'Tianhe-2A-TH-IVB-FEPCluster, IntelXeonE5-2692v212C2.2GHz, THExpress-2, Matrix-2000, NUDTNationalSuperComputerCenterinGuangzhouChina',
#   '4981760',
#   '61.44',
#   '100.68',
#   '18482'],
#  ['108',
#   'AdvancedComputingSystem(PreE)-SugonTC8600, HygonDhyana32C2GHz, DeepComputingProcessor, 200Gb6D-Torus, SugonSugonChina',
#   '163840',
#   '4.33',
#   '6.13',
#   '380'],
#  ['132',
#   'ThinkSystemSD650V2, XeonPlatinum835832C2.6GHz, MellanoxHDRInfiniband, LenovoShanghaiJiaoTongUniversityChina',
#   '59392',
#   '3.49',
#   '4.94',
#   ''],
#  ['158',
#   'LenovoHR650x, XeonGold613320C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '76000',
#   '3.09',
#   '6.08',
#   ''],
#  ['165',
#   'LenovoHR650x, XeonGold613320C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '73600',
#   '2.99',
#   '5.89',
#   ''],
#  ['166',
#   'HHH1-ThinkSystemHR650X, XeonGold623324C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '80640',
#   '2.98',
#   '6.45',
#   ''],
#  ['167',
#   'III1-ThinkSystemHR650X, XeonGold623324C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '79680',
#   '2.98',
#   '6.37',
#   ''],
#  ['169',
#   'JJJ1-ThinkSystemHR650X, XeonGold623324C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '78720',
#   '2.93',
#   '6.30',
#   ''],
#  ['170',
#   'LenovoHR650x, XeonGold613320C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '72000',
#   '2.93',
#   '5.76',
#   ''],
#  ['174',
#   'KKK1-ThinkSystemHR650X, XeonGold623324C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '77760',
#   '2.91',
#   '6.22',
#   ''],
#  ['175',
#   'InspurTS10000HPCServer, XeonGold6248R24C3GHz, InfiniBandHDR100, InspurCentralSouthUniversityChina',
#   '49056',
#   '2.89',
#   '4.71',
#   ''],
#  ['176',
#   'LLL1-ThinkSystemHR650X, XeonGold623324C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '76800',
#   '2.88',
#   '6.14',
#   ''],
#  ['177',
#   'ThinkSystemHR650X, XeonGold6230R26C2.1GHz, 10GEthernet, LenovoServiceProviderKChina',
#   '93600',
#   '2.87',
#   '6.29',
#   ''],
#  ['181',
#   'ThinkSystemSR650, XeonGold623822C2.1GHz, 10GEthernet, LenovoFinancialServicesPChina',
#   '94160',
#   '2.87',
#   '6.33',
#   ''],
#  ['182',
#   'MMM1-ThinkSystemHR650X, XeonGold623324C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '75840',
#   '2.86',
#   '6.07',
#   ''],
#  ['184',
#   'NNN1-ThinkSystemHR650X, XeonGold623324C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '74880',
#   '2.83',
#   '5.99',
#   ''],
#  ['187',
#   'OOO1-ThinkSystemHR650X, XeonGold623324C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '73920',
#   '2.80',
#   '5.91',
#   ''],
#  ['191',
#   'LenovoHR650x, XeonGold613320C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '68000',
#   '2.78',
#   '5.44',
#   ''],
#  ['192',
#   'ThinkSystemHR650X, XeonGold623324C2.5GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '72960',
#   '2.77',
#   '5.84',
#   ''],
#  ['194',
#   'ZZ2-ThinkSystemHR650X, XeonGold613320C2.5GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '67200',
#   '2.75',
#   '5.38',
#   ''],
#  ['195',
#   'ThinkSystemSR650, XeonGold624820C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '66400',
#   '2.75',
#   '5.31',
#   ''],
#  ['196',
#   'ThinkSystemSR650, XeonGold624018C2.6GHz, NVIDIATeslaV100, InfinibandEDR, LenovoGovernmentChina',
#   '59976',
#   '2.74',
#   '5.35',
#   ''],
#  ['197',
#   'ThinkSystemHR650X, XeonGold623324C2.5GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '72000',
#   '2.74',
#   '5.76',
#   ''],
#  ['201',
#   'ZZ3-ThinkSystemHR650X, XeonGold613320C2.5GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '66400',
#   '2.72',
#   '5.31',
#   ''],
#  ['202',
#   'ThinkSystemHR650X, XeonGold623324C2.5GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '71040',
#   '2.71',
#   '5.68',
#   ''],
#  ['203',
#   'ZZ4-ThinkSystemHR650X, XeonGold613320C2.5GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '65600',
#   '2.69',
#   '5.25',
#   ''],
#  ['204',
#   'ThinkSystemHR650X, XeonGold623324C2.5GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '70080',
#   '2.68',
#   '5.61',
#   ''],
#  ['207',
#   'ZZ5-ThinkSystemHR650X, XeonGold613320C2.5GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '64800',
#   '2.66',
#   '5.18',
#   ''],
#  ['208',
#   'ZZ6-ThinkSystemHR650X, XeonGold623324C2.5GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '69120',
#   '2.65',
#   '5.53',
#   ''],
#  ['209',
#   'ThinkSystemSR590, XeonGold521816C2.3GHz, 10GEthernet, LenovoCloudCompanyChina',
#   '128000',
#   '2.65',
#   '4.71',
#   ''],
#  ['213',
#   'LenovoHR650x, XeonGold613320C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '64000',
#   '2.62',
#   '5.12',
#   ''],
#  ['215',
#   'InspurTS10000, XeonGold6258R28C2.7GHz, InfiniBandHDR100, InspurTsinghuaUniversityChina',
#   '50400',
#   '2.61',
#   '4.35',
#   ''],
#  ['219',
#   'ThinkSystemHR650X, XeonGold623324C2.5GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '68160',
#   '2.61',
#   '5.45',
#   ''],
#  ['224',
#   'ThinkSystemSR650, XeonGold624820C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '62400',
#   '2.59',
#   '4.99',
#   ''],
#  ['225',
#   'ThinkSystemHR650X, XeonGold623324C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '64320',
#   '2.58',
#   '5.15',
#   ''],
#  ['226',
#   'ThinkSystemHR650X, XeonGold6230R26C2.1GHz, 10GEthernet, LenovoServiceProviderKChina',
#   '83200',
#   '2.58',
#   '5.59',
#   ''],
#  ['227',
#   'ThinkSystemHR650X, XeonGold623324C2.5GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '67200',
#   '2.57',
#   '5.38',
#   ''],
#  ['229',
#   'Tianhe-1A-NUDTYHMPP, XeonX56706C2.93GHz, NVIDIA2050, NUDTNationalSupercomputingCenterinTianjinChina',
#   '186368',
#   '2.57',
#   '4.70',
#   '4040'],
#  ['231',
#   'PAI-BSystem-SugonTC4600LP/W740I, XeonGold614216C2.6GHz, InfinibandEDR, NVIDIATeslaP100, SugonChinaMeteorologicalAdministrationChina',
#   '50816',
#   '2.55',
#   '4.23',
#   '710'],
#  ['235',
#   'ThinkSystemHR650X, XeonGold623324C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '61440',
#   '2.49',
#   '4.92',
#   ''],
#  ['239',
#   'InspurNF5468M5, XeonGold624216C2.8GHz, NVIDIATeslaV100, 100GEthernet, InspurManufacturingIndustry(O)China',
#   '50400',
#   '2.48',
#   '4.68',
#   ''],
#  ['240',
#   'InspurNF5468M5, XeonGold624216C2.8GHz, NVIDIATeslaV100, 100GEthernet, InspurManufacturingIndustry(O)China',
#   '50400',
#   '2.48',
#   '4.68',
#   ''],
#  ['243',
#   'B1-LenovoHR650x, XeonGold613320C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '60000',
#   '2.46',
#   '4.80',
#   ''],
#  ['245',
#   'PAI-ASystem-SugonTC4600, XeonGold614216C2.6GHz, InfinibandEDR, SugonChinaMeteorologicalAdministrationChina',
#   '48128',
#   '2.44',
#   '4.00',
#   '740'],
#  ['246',
#   'C1-LenovoHR650x, XeonGold613320C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '59200',
#   '2.43',
#   '4.74',
#   ''],
#  ['248',
#   'ThinkSystemSR590, XeonGold521816C2.3GHz, 10GEthernet, LenovoDJITCompanyChina',
#   '115200',
#   '2.43',
#   '4.24',
#   ''],
#  ['249',
#   'D1-LenovoHR650x, XeonGold613320C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '58800',
#   '2.42',
#   '4.70',
#   ''],
#  ['250',
#   'ThinkSystemSR590, XeonGold521816C2.3GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '113600',
#   '2.40',
#   '4.18',
#   ''],
#  ['253',
#   'E1-LenovoHR650x, XeonGold613320C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '58000',
#   '2.39',
#   '4.64',
#   ''],
#  ['254',
#   'ThinkSystemHR650X, XeonGold623324C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '58560',
#   '2.38',
#   '4.68',
#   ''],
#  ['255',
#   'ThinkSystemSR590, XeonGold521816C2.3GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '112000',
#   '2.37',
#   '4.12',
#   ''],
#  ['263',
#   'ZZ1-ThinkSystemHR630X, XeonSilver41108C2.1GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '153600',
#   '2.35',
#   '10.32',
#   ''],
#  ['268',
#   'InspurNF5468M5, Xeon8260M24C2.4GHz, NVIDIATeslaV100, 100GEthernet, InspurInternetCompanyChina',
#   '48160',
#   '2.34',
#   '4.37',
#   ''],
#  ['269',
#   'InspurNF5468M5, Xeon8260M24C2.4GHz, NVIDIATeslaV100, 100GEthernet, InspurInternetCompanyChina',
#   '48160',
#   '2.34',
#   '4.37',
#   ''],
#  ['271',
#   'InspurNF5468M5, XeonGold613016C2.1GHz, NVIDIATeslaV100, 25GEthernet, InspurInternetServicePChina',
#   '53760',
#   '2.33',
#   '4.48',
#   ''],
#  ['272',
#   'InspurNF5468M5, XeonGold613016C2.1GHz, NVIDIATeslaV100, 25GEthernet, InspurInternetServicePChina',
#   '53760',
#   '2.33',
#   '4.48',
#   ''],
#  ['273',
#   'InspurNF5468M5, XeonGold613016C2.1GHz, NVIDIATeslaV100, 25GEthernet, InspurInternetServicePChina',
#   '53760',
#   '2.33',
#   '4.48',
#   ''],
#  ['275',
#   'F1-LenovoHR650x, XeonGold613320C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '56000',
#   '2.32',
#   '4.48',
#   ''],
#  ['276',
#   'InspurTS10000HPCServer, XeonGold6226R16C2.9GHz, NVIDIATeslaV100, 25GEthernet, InspurEnergyCompanyBChina',
#   '49920',
#   '2.32',
#   '4.41',
#   ''],
#  ['277',
#   'ThinkSystemSR590, XeonGold521816C2.3GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '108800',
#   '2.31',
#   '4.00',
#   ''],
#  ['281',
#   'InspurTS10000, XeonGold613016C2.1GHz, NVIDIATeslaV100, 25GEthernet, InspurInternetServicePChina',
#   '55104',
#   '2.29',
#   '4.89',
#   ''],
#  ['283',
#   'InspurNF5468M5, XeonGold624018C2.6GHz, NVIDIATeslaV100, 25GEthernet, InspurTelecomOperator(C)China',
#   '47320',
#   '2.28',
#   '4.37',
#   ''],
#  ['284',
#   'InspurNF5468M5, XeonGold624018C2.6GHz, NVIDIATeslaV100, 25GEthernet, InspurTelecomOperator(C)China',
#   '47320',
#   '2.28',
#   '4.37',
#   ''],
#  ['285',
#   'InspurNF5468M5, XeonGold624018C2.6GHz, NVIDIATeslaV100, 25GEthernet, InspurTelecomOperator(C)China',
#   '47320',
#   '2.28',
#   '4.37',
#   ''],
#  ['286',
#   'InspurNF5468M5, XeonGold624018C2.6GHz, NVIDIATeslaV100, 25GEthernet, InspurTelecomOperator(C)China',
#   '47320',
#   '2.28',
#   '4.37',
#   ''],
#  ['289',
#   'InspurTS10000HPCServer, XeonGold624018C2.6GHz, NVIDIATeslaV100, InfiniBandHDR100, InspurResearchLaboratoryHChina',
#   '40560',
#   '2.28',
#   '3.92',
#   ''],
#  ['290',
#   'InspurTS10000HPCServer, XeonGold623020C2.1GHz, NVIDIATeslaV100, InfinibandHDR, InspurAIcompanyJChina',
#   '40800',
#   '2.27',
#   '3.91',
#   ''],
#  ['297',
#   'G1-LenovoHR650x, XeonGold613320C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '54000',
#   '2.24',
#   '4.32',
#   ''],
#  ['298',
#   'ThinkSystemHR650X, XeonGold623324C2.5GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '57600',
#   '2.24',
#   '4.61',
#   ''],
#  ['299',
#   'SugonTC6000, XeonGold613016C2.1GHz, 25GEthernet, SugonInternetCompanyChina',
#   '67200',
#   '2.19',
#   '4.52',
#   '740'],
#  ['300',
#   'InspurNF5468M5, XeonGold624820C2.5GHz, NVIDIATeslaV100, 25GEthernet, InspurBankGChina',
#   '50400',
#   '2.19',
#   '4.82',
#   ''],
#  ['305',
#   'H1-LenovoHR650x, XeonGold613320C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '52000',
#   '2.17',
#   '4.16',
#   ''],
#  ['306',
#   'InspurNF5468M5, XeonGold614612C3.2GHz, NVIDIATeslaV100, InfinibandEDR, InspurInternetService(S)China',
#   '49800',
#   '2.16',
#   '4.42',
#   ''],
#  ['307',
#   'InspurNF5468M5, XeonGold614612C3.2GHz, NVIDIATeslaV100, InfinibandEDR, InspurInternetService(S)China',
#   '49800',
#   '2.16',
#   '4.42',
#   ''],
#  ['308',
#   'InspurNF5468M5, XeonGold614612C3.2GHz, NVIDIATeslaV100, InfinibandEDR, InspurInternetService(S)China',
#   '49800',
#   '2.16',
#   '4.42',
#   ''],
#  ['309',
#   'ThinkSystemHR630X, XeonSilver41108C2.1GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '128000',
#   '2.16',
#   '4.30',
#   ''],
#  ['310',
#   'SugonTC6000, XeonGold511812C2.3GHz, 10GEthernet, SugonInternetCompanyChina',
#   '121920',
#   '2.15',
#   '8.97',
#   '1625'],
#  ['312',
#   'ThinkSystemSR650, XeonGold521816C2.3GHz, 10GEthernet, LenovoDJITCompanyChina',
#   '96640',
#   '2.13',
#   '7.11',
#   ''],
#  ['315',
#   'INSPURNF5288M5, XeonGold614820C2.4GHz, NVIDIATeslaV100, 25GEthernet, InspurBank(Z)China',
#   '44200',
#   '2.12',
#   '4.06',
#   ''],
#  ['316',
#   'InspurNF5468M5, XeonPlatinum816324C2.5GHz, NVIDIATeslaV100, 25GEthernet, InspurServiceProviderTChina',
#   '44720',
#   '2.12',
#   '4.06',
#   ''],
#  ['317',
#   'InspurNF5468M5, XeonPlatinum816324C2.5GHz, NVIDIATeslaV100, 25GEthernet, InspurServiceProviderTChina',
#   '44720',
#   '2.12',
#   '4.06',
#   ''],
#  ['318',
#   'InspurNF5468M5, XeonPlatinum816324C2.5GHz, NVIDIATeslaV100, 25GEthernet, InspurServiceProviderTChina',
#   '44720',
#   '2.12',
#   '4.06',
#   ''],
#  ['319',
#   'SugonTC6000, XeonGold511812C2.3GHz, NVIDIATeslaV100, InfinibandEDR, SugonXinjiangSCCenterChina',
#   '44720',
#   '2.12',
#   '3.90',
#   '265'],
#  ['320',
#   'INSPURNF5288M5, XeonGold613016C2.1GHz, NVIDIATeslaV100, 100GEthernet, InspurInternetCompanyChina',
#   '53760',
#   '2.11',
#   '4.65',
#   ''],
#  ['321',
#   'MagicCube3-SugonTC6000, XeonGold614216C2.6GHz, IntelOmni-Path, NVIDIATeslaV100, SugonShanghaiSupercomputerCenterChina',
#   '40960',
#   '2.11',
#   '3.43',
#   '430'],
#  ['322',
#   'I1-LenovoHR650x, XeonGold613320C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '50000',
#   '2.09',
#   '4.00',
#   ''],
#  ['325',
#   'SugonTC6000, XeonGold511812C2.3GHz, NVIDIATeslaV100, 25GEthernet, SugonInternetServiceUChina',
#   '44032',
#   '2.09',
#   '3.84',
#   '260'],
#  ['326',
#   'InspurNF5468M5, XeonPlatinum816324C2.5GHz, NVIDIATeslaV100, 25GEthernet, InspurServiceProviderTChina',
#   '48160',
#   '2.08',
#   '4.23',
#   ''],
#  ['327',
#   'InspurNF5468M5, XeonPlatinum816324C2.5GHz, NVIDIATeslaV100, 25GEthernet, InspurServiceProviderTChina',
#   '48160',
#   '2.08',
#   '4.23',
#   ''],
#  ['328',
#   'InspurNF5468M5, XeonPlatinum816324C2.5GHz, NVIDIATeslaV100, 25GEthernet, InspurServiceProviderTChina',
#   '48160',
#   '2.08',
#   '4.23',
#   ''],
#  ['330',
#   'InspurNF5468M5, XeonGold511812C2.3GHz, NVIDIATeslaV100, 10GEthernet, InspurTelecomCompanyChina',
#   '59760',
#   '2.08',
#   '5.25',
#   ''],
#  ['331',
#   'JDI1-ThinkSystemSR650, XeonGold614820C2.4GHz, 10GEthernet, LenovoInternetCompanyChina',
#   '52320',
#   '2.07',
#   '4.02',
#   ''],
#  ['332',
#   'Tianhe-2LvLiangSolution-Tianhe-2LvLiang, IntelXeonE5-2692v212C2.2GHz, THExpress-2, IntelXeonPhi31S1P, NUDTLvLiangCloudComputingCenterChina',
#   '174720',
#   '2.07',
#   '3.07',
#   '997'],
#  ['334',
#   'ThinkSystemSR650, XeonGold614216C2.6GHz, NVIDIATeslaV100, InfinibandEDR, LenovoGovernmentChina',
#   '44160',
#   '2.06',
#   '3.86',
#   ''],
#  ['335',
#   'ThinkSystemSR650, XeonGold624820C2.5GHz, 10GEthernet, LenovoDJITCompanyChina',
#   '49200',
#   '2.05',
#   '3.94',
#   ''],
#  ['336',
#   'INSPURNF5288M5, XeonGold614820C2.4GHz, NVIDIATeslaV100, 10GEthernet, InspurInternetService(B)China',
#   '53040',
#   '2.03',
#   '4.65',
#   ''],
#  ['337',
#   'INSPURNF5288M5, XeonGold614820C2.4GHz, NVIDIATeslaV100, 10GEthernet, InspurInternetService(B)China',
#   '53040',
#   '2.03',
#   '4.65',
#   ''],
#  ['338',
#   'ThinkSystemHR650X, XeonGold613320C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '48000',
#   '2.03',
#   '3.84',
#   ''],
#  ['339',
#   'SugonTC6000, XeonGold614018C2.3GHz, 10GEthernet, SugonTelecomCompanyChina',
#   '55440',
#   '2.03',
#   '4.08',
#   '590'],
#  ['340',
#   'InspurNF5468M5, XeonGold512014C2.2GHz, NVIDIATeslaV100, 10GEthernet, InspurBankIChina',
#   '48880',
#   '2.02',
#   '44.98',
#   ''],
#  ['342',
#   'J1-LenovoHR650x, XeonGold613320C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '48000',
#   '2.01',
#   '3.84',
#   ''],
#  ['343',
#   'InspurNF5468M5, XeonPlatinum8260M24C2.4GHz, NVIDIATeslaV100, 100GEthernet, InspurInternetCompanyChina',
#   '41280',
#   '2.01',
#   '3.74',
#   ''],
#  ['344',
#   'InspurNF5468M5, XeonGold623020C2.1GHz, NVIDIATeslaV100, 25GEthernet, InspurManufacturingCompany(V)China',
#   '40800',
#   '2.01',
#   '3.74',
#   ''],
#  ['345',
#   'SugonTC6000, XeonGold511812C2.3GHz, 10GEthernet, SugonInternetCompanyChina',
#   '110880',
#   '2.01',
#   '8.16',
#   '1470'],
#  ['346',
#   'SugonTC6000, XeonGold511812C2.3GHz, NVIDIATeslaV100, 25GEthernet, SugonInternetCompanyChina',
#   '42312',
#   '2.00',
#   '3.69',
#   '250'],
#  ['351',
#   'TTSystem-SugonTC6000, XeonE5-2630v410C2.2GHz, 10GEthernet, SugonInternetService(B)China',
#   '116600',
#   '2.00',
#   '4.10',
#   '1200'],
#  ['352',
#   'SugonTC6000, XeonGold614820C2.4GHz, InfinibandEDR, SugonChengduSCCenterChina',
#   '520000',
#   '1.99',
#   '39.94',
#   '510'],
#  ['353',
#   'K1-LenovoHR650x, XeonGold613320C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '47200',
#   '1.98',
#   '3.78',
#   ''],
#  ['355',
#   'HKVDPSystem-SugonTC6000, XeonE5-2620v48C2.1GHz, 10GEthernet, SugonITServiceProviderChina',
#   '121920',
#   '1.98',
#   '4.10',
#   '1216'],
#  ['356',
#   'HKVDPSystem-SugonTC6000, XeonE5-2620v48C2.1GHz, 10GEthernet, SugonInternetCompanyChina',
#   '121920',
#   '1.98',
#   '4.10',
#   '1216'],
#  ['357',
#   'bsystem-SugonTC6000, XeonGold613016C2.1GHz, 25GEthernet, SugonInternetCompanyChina',
#   '60800',
#   '1.98',
#   '4.09',
#   '660'],
#  ['358',
#   'ThinkSystemSR590, XeonGold521816C2.3GHz, 10GEthernet, LenovoDJITCompanyChina',
#   '89600',
#   '1.98',
#   '6.59',
#   ''],
#  ['359',
#   'InspurNF5468M5, XeonGold614612C3.2GHz, NVIDIATeslaV100, InfinibandEDR, InspurInternetService(S)China',
#   '45152',
#   '1.98',
#   '4.01',
#   ''],
#  ['360',
#   'InspurNF5468M5, XeonGold614612C3.2GHz, NVIDIATeslaV100, 25GEthernet, InspurServiceProviderTChina',
#   '45152',
#   '1.98',
#   '4.01',
#   ''],
#  ['361',
#   'InspurNF5468M5, XeonGold614612C3.2GHz, NVIDIATeslaV100, 25GEthernet, InspurServiceProviderTChina',
#   '45152',
#   '1.98',
#   '4.01',
#   ''],
#  ['366',
#   'SugonTC6000, XeonGold511812C2.3GHz, 25GEthernet, NVIDIATeslaV100, SugonEnergyCompanyChina',
#   '41280',
#   '1.96',
#   '3.60',
#   '245'],
#  ['367',
#   'SugonTC6000, XeonGold613214C2.6GHz, 25GEthernet, SugonTelecomCompanyChina',
#   '47600',
#   '1.96',
#   '3.96',
#   '650'],
#  ['368',
#   'SugonTC6000, XeonGold614018C2.3GHz, 10GEthernet, SugonStateGridCorpChina',
#   '53280',
#   '1.95',
#   '3.92',
#   '570'],
#  ['369',
#   'SugonTC6000, XeonGold613016C2.1GHz, 25GEthernet, SugonITServiceProviderChina',
#   '58112',
#   '1.93',
#   '3.91',
#   '630'],
#  ['370',
#   'InspurNF5468M5, XeonGold613214C2.6GHz, NVIDIATeslaV100, 25GEthernet, InspurBank(J)China',
#   '51504',
#   '1.93',
#   '4.62',
#   ''],
#  ['371',
#   'CTcluster-SugonTC6000, XeonGold614018C2.3GHz, 10GEthernet, SugonTelecomCompanyChina',
#   '54000',
#   '1.93',
#   '3.97',
#   '520'],
#  ['372',
#   'InspurTS10000, XeonGold613016C2.1GHz, NVIDIATeslaV100, InfinibandEDR, InspurInternetCompanyChina',
#   '40320',
#   '1.92',
#   '3.52',
#   ''],
#  ['373',
#   'ThinkSystemSR650, XeonGold613820C2GHz, 10GEthernet, LenovoFinancialCompanyPChina',
#   '57200',
#   '1.91',
#   '3.66',
#   ''],
#  ['374',
#   'Huawei2288HV5, XeonGold615018C2.7GHz, 10GEthernet, HuaweiTechnologiesCo., Ltd.EnergyCompanyChina',
#   '49680',
#   '1.91',
#   '4.29',
#   '733'],
#  ['375',
#   'ThinkSystemSR650, XeonE5-2698v316C2.3GHz, 10GEthernet, LenovoDJITCompanyChina',
#   '86400',
#   '1.91',
#   '3.18',
#   ''],
#  ['376',
#   'SugonTC6000, XeonGold613214C2.6GHz, 25GEthernet, SugonDJITCompanyChina',
#   '46200',
#   '1.90',
#   '3.84',
#   '630'],
#  ['378',
#   'SugonTC6000, XeonGold613016C2.1GHz, 25GEthernet, SugonInternetCompanyChina',
#   '56800',
#   '1.90',
#   '3.82',
#   '625'],
#  ['380',
#   'A1-LenovoHR650x, XeonGold614820C2.4GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '47040',
#   '1.88',
#   '3.61',
#   ''],
#  ['381',
#   'INSPURSA5212M5, XeonGold511714C2GHz, NVIDIATeslaV100, 10GEthernet, InspurInternetService(B)China',
#   '173680',
#   '1.87',
#   '15.16',
#   ''],
#  ['382',
#   'InspurTS10000, XeonGold613016C2.1GHz, NVIDIATeslaV100, 25GEthernet, InspurInternetServicePChina',
#   '40320',
#   '1.87',
#   '3.52',
#   ''],
#  ['385',
#   'ThinkSystemSR650, XeonGold624820C2.5GHz, 10GEthernet, LenovoDJITCompanyChina',
#   '44000',
#   '1.86',
#   '3.52',
#   ''],
#  ['386',
#   'InspurNF5468M5, XeonGold511812C2.3GHz, NVIDIATeslaV100, 25GEthernet, InspurInternetServicePChina',
#   '46480',
#   '1.85',
#   '4.08',
#   ''],
#  ['387',
#   'InspurTS10000, XeonGold624820C2.5GHz/Platinum826824C2.9GHz, NVIDIATeslaV100, 100GEthernet, InspurNanjingUniversityChina',
#   '37440',
#   '1.85',
#   '3.43',
#   ''],
#  ['390',
#   'bsystem-SugonTC6000, XeonGold613016C2.1GHz, 25GEthernet, SugonInternetCompanyChina',
#   '55040',
#   '1.84',
#   '3.70',
#   '600'],
#  ['391',
#   'ThinkSystemSR570, XeonGold521816C2.3GHz, 10GEthernet, LenovoDJITCompanyChina',
#   '83200',
#   '1.84',
#   '6.12',
#   ''],
#  ['392',
#   'SugonTC6000, XeonGold614820C2.4GHz, 25GEthernet, SugonDJITCompanyChina',
#   '48000',
#   '1.83',
#   '3.69',
#   '470'],
#  ['394',
#   'SugonTC6000, XeonGold511714C2GHz, 25GEthernet, SugonInternetService(B)China',
#   '116200',
#   '1.83',
#   '7.44',
#   '1300'],
#  ['395',
#   'LenovoHR650x, XeonGold613320C2.5GHz, 25GEthernet, LenovoServiceProviderTChina',
#   '43200',
#   '1.83',
#   '3.46',
#   ''],
#  ['397',
#   'ThinkSystemSR650, XeonGold613820C2GHz, 10GEthernet, NVIDIATeslaP100, LenovoFinancialCompanyPChina',
#   '66080',
#   '1.83',
#   '4.98',
#   ''],
#  ['399',
#   'JGV100System-SugonTC6000, XeonE5-2680v414C2.4GHz, NVIDIATeslaV100, 10GEthernet, SugonInternetCompanyChina',
#   '41760',
#   '1.82',
#   '3.35',
#   '240'],
#  ['400',
#   'SugonTC6000, XeonGold613214C2.6GHz, 10GEthernet, SugonITServiceProviderChina',
#   '44100',
#   '1.82',
#   '3.67',
#   '600'],
#  ['401',
#   'INSPURSA5212M5, XeonGold511714C2GHz, NVIDIATeslaV100, 10GEthernet, InspurInternetService(B)China',
#   '48880',
#   '1.82',
#   '4.14',
#   ''],
#  ['402',
#   'INSPURSA5212M5, XeonGold511714C2GHz, NVIDIATeslaV100, 10GEthernet, InspurInternetService(B)China',
#   '48880',
#   '1.82',
#   '4.14',
#   ''],
#  ['404',
#   'SugonTC6000, XeonGold613016C2.1GHz, 25GEthernet, SugonGovernmentAgency(S)China',
#   '54240',
#   '1.81',
#   '3.64',
#   '600'],
#  ['405',
#   'szaisystem-SugonTC6000, XeonGold624820C2.5GHz, NVIDIATeslaV100, InfinibandEDR, SugonSuzhouSCcenterChina',
#   '30600',
#   '1.81',
#   '2.67',
#   '180'],
#  ['406',
#   'BankPA2-ThinkSystemSR650, XeonGold614820C2.4GHz, NVIDIATeslaV100, 10GEthernet, LenovoFinancialCompanyPChina',
#   '36000',
#   '1.81',
#   '3.02',
#   ''],
#  ['407',
#   'BankPA2-ThinkSystemSR650, XeonGold614820C2.4GHz, NVIDIATeslaV100, 10GEthernet, LenovoFinancialCompanyPChina',
#   '36000',
#   '1.81',
#   '3.02',
#   ''],
#  ['408',
#   'JCSystem-SugonTC6000, XeonE5-2620v48C2.1GHz, 10GEthernet, SugonInternetCompanyChina',
#   '110080',
#   '1.81',
#   '3.70',
#   '1100'],
#  ['409',
#   'S1-ThinkSystemFlexSN550, XeonGold615018C2.7GHz, InfinibandFDR, LenovoGovernmentChina',
#   '33840',
#   '1.80',
#   '2.92',
#   ''],
#  ['411',
#   'ESSystem-SugonTC6000, XeonE5-2630v410C2.2GHz, 10GEthernet, SugonStateGridCorpChina',
#   '105000',
#   '1.79',
#   '3.70',
#   '1100'],
#  ['413',
#   'R1-ThinkSystemFlexSN550, XeonGold615018C2.7GHz, InfinibandFDR, LenovoGovernmentChina',
#   '33120',
#   '1.77',
#   '2.86',
#   ''],
#  ['414',
#   'ThinkSystemSR570, XeonGold521816C2.3GHz, 10GEthernet, LenovoDJITCompanyChina',
#   '80000',
#   '1.77',
#   '5.89',
#   ''],
#  ['415',
#   'SugonTC6000, XeonGold511812C2.3GHz, 10GEthernet, SugonInternetCompanyChina',
#   '99360',
#   '1.76',
#   '7.31',
#   '1320'],
#  ['419',
#   'ThinkSystemSR590, XeonE7-4850V314C2.2GHz, 10GEthernet, LenovoDJITCompanyChina',
#   '2312800',
#   '1.74',
#   '81.41',
#   ''],
#  ['420',
#   'CSystem-SugonTC6000, XeonGold511812C2.3GHz, 10GEthernet, SugonTelecomOperator(C)China',
#   '97920',
#   '1.74',
#   '7.21',
#   '1000'],
#  ['421',
#   'Q1-ThinkSystemFlexSN550, XeonGold615018C2.7GHz, InfinibandFDR, LenovoGovernmentChina',
#   '32400',
#   '1.74',
#   '2.80',
#   ''],
#  ['422',
#   'InspurSA5212H5, XeonPlatinum816324C2.5GHz, 10GEthernet, InspurInternetServiceAChina',
#   '38400',
#   '1.73',
#   '3.07',
#   ''],
#  ['423',
#   'InspurSA5212H5, XeonPlatinum816324C2.5GHz, 10GEthernet, InspurInternetServiceAChina',
#   '38400',
#   '1.73',
#   '3.07',
#   ''],
#  ['424',
#   'InspurSA5212H5, XeonPlatinum816324C2.5GHz, 10GEthernet, InspurInternetServiceAChina',
#   '38400',
#   '1.73',
#   '3.07',
#   ''],
#  ['425',
#   'InternetCompanyTDD1-LenovoRD350, XeonE5-2620v48C2.1GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '118400',
#   '1.73',
#   '3.98',
#   ''],
#  ['429',
#   'InspurTS10000, XeonE5-2682v416C2.5GHz, 10GEthernet, NVIDIATeslaP100, InspurInternetServiceAChina',
#   '39680',
#   '1.71',
#   '3.15',
#   ''],
#  ['431',
#   'P1-ThinkSystemFlexSN550, XeonGold615018C2.7GHz, InfinibandFDR, LenovoGovernmentChina',
#   '31680',
#   '1.70',
#   '2.74',
#   ''],
#  ['434',
#   'TaiYi-ThinkSystemSD530, XeonGold614820C2.4GHz, IntelOmni-Path, LenovoSouthernUniversityofScienceandTechnologyChina',
#   '32400',
#   '1.69',
#   '2.49',
#   ''],
#  ['436',
#   'ThinkSystemSD530, XeonGold614820C2.4GHz, InfinibandEDR, LenovoGovernmentChina',
#   '35200',
#   '1.68',
#   '2.70',
#   ''],
#  ['437',
#   'ThinkSystemSD650, XeonGold624018C2.6GHz, InfinibandEDR, LenovoBeijingMeteorologicalAssociationChina',
#   '28800',
#   '1.68',
#   '2.70',
#   ''],
#  ['438',
#   'ISystem-SugonTC6000, XeonE5-2650v412C2.2GHz, 10GEthernet, SugonIITCompanyChina',
#   '97920',
#   '1.68',
#   '3.45',
#   '1050'],
#  ['439',
#   'InternetServiceD-Huawei1288HV5, XeonPlatinum816024C2.1GHz, InfinibandEDR, HuaweiTechnologiesCo., Ltd.InternetServiceJChina',
#   '48960',
#   '1.67',
#   '3.29',
#   '524'],
#  ['441',
#   'O1-ThinkSystemFlexSN550, XeonGold615018C2.7GHz, InfinibandFDR, LenovoGovernmentChina',
#   '30960',
#   '1.67',
#   '2.67',
#   ''],
#  ['442',
#   'ThinkSystemSR650, XeonGold614820C2.4GHz, 10GEthernet, LenovoInternetCompanyChina',
#   '41760',
#   '1.67',
#   '3.21',
#   ''],
#  ['443',
#   'SugonTC6000, AMDEpyc750132C2GHz, AMDVega20, InfinibandHDR, SugonPukouAdvancedComputingCenterChina',
#   '100800',
#   '1.66',
#   '2.47',
#   '260'],
#  ['445',
#   'InternetCompanyTY1-LenovoRD450, XeonE5-2680v414C2.4GHz, 10GEthernet, LenovoServiceProviderTChina',
#   '89600',
#   '1.65',
#   '3.44',
#   ''],
#  ['446',
#   'ThinkSystemSR570, XeonE7-4850V314C2.2GHz, 10GEthernet, LenovoDJITCompanyChina',
#   '78400',
#   '1.65',
#   '2.76',
#   '']]
